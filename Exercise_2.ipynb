# %%
# importing libraries --1
import pandas as pd
import numpy as np

# %%
# Create an example dataframe about a fictional army --2
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %%
#Create a dataframe and assign it to a variable called army.--3
army = pd.DataFrame(raw_data , columns = ['regiment' , 'company', 'deaths' , 'battles' , 'size' , 'veterans', 'readiness' ,'readiness' , 'armored' , 'deserters' ,'origin'])

# %%
#Set the 'origin' colum as the index of the dataframe --4
army.set_index('origin', inplace = True)

# %%
army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
#Print only the column veterans --5
print(army['veterans'].to_string(index=False))
# Out:
# origin
#   1
#   5
#  62
#  26
#  73
#  37
# 949
#  48
#  48
# 435
#  63
# 345

# %%
#Print the columns 'veterans' and 'deaths' --6
print(army[['veterans' , 'deaths']].to_string(index=False))
# Out:
#  veterans  deaths
#         1     523
#         5      52
#        62      25
#        26     616
#        73      43
#        37     234
#       949     523
#        48      62
#        48      62
#       435      73
#        63      37
#       345      35

# %%
#Print the name of all the columns. --7
print(army.columns)
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'readiness', 'armored', 'deserters'],
#       dtype='object')

# %%
army.dtypes
# Out:
# regiment     object
# company      object
# deaths        int64
# battles       int64
# size          int64
# veterans      int64
# readiness     int64
# readiness     int64
# armored       int64
# deserters     int64
# dtype: object

# %%
#Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska --8
army[['deaths' , 'size' , 'deserters']].loc[['Alaska','Maine']]
# Out:
#         deaths  size  deserters
# origin
# Alaska     523   987         24
# Maine       43  1592          3

# %%
#Select the rows 3 to 7 and the columns 3 to 6 --9
army.iloc[2:7 , 1:5]
# Out:
#         company  deaths  battles  size
# origin
# Texas       2nd      25        2  1099
# Florida     2nd     616        2  1400
# Maine       1st      43        4  1592
# Iowa        1st     234        7  1006
# Alaska      2nd     523        8   987

# %%
#Select every row after the fourth row and all columns --10
army.iloc[4:,:]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Maine       Dragoons     1st      43        4  1592        73          2
# Iowa        Dragoons     1st     234        7  1006        37          1
# Alaska      Dragoons     2nd     523        8   987       949          2
# Washington  Dragoons     2nd      62        3   849        48          3
# Oregon        Scouts     1st      62        4   973        48          2
# Wyoming       Scouts     1st      73        7  1005       435          1
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#             readiness  armored  deserters
# origin
# Maine               2        0          3
# Iowa                1        1          4
# Alaska              2        0         24
# Washington          3        1         31
# Oregon              2        0          2
# ...

# %%
#Select every row up to the 4th row and all columns --11
army.iloc[:4,:]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
#
#             readiness  armored  deserters
# origin
# Arizona             1        1          4
# California          2        0         24
# Texas               3        1         31
# Florida             3        1          2

# %%
#Select the 3rd column up to the 7th column --12
army.iloc[:,1:6]
# Out:
#            company  deaths  battles  size  veterans
# origin
# Arizona        1st     523        5  1045         1
# California     1st      52       42   957         5
# Texas          2nd      25        2  1099        62
# Florida        2nd     616        2  1400        26
# Maine          1st      43        4  1592        73
# Iowa           1st     234        7  1006        37
# Alaska         2nd     523        8   987       949
# Washington     2nd      62        3   849        48
# Oregon         1st      62        4   973        48
# Wyoming        1st      73        7  1005       435
# Louisana       2nd      37        8  1099        63
# Georgia        2nd      35        9  1523       345

# %%
#Select rows where df.deaths is greater than 50 --13
result = army[army['deaths'] > 50]
result
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
#
#             readiness  armored  deserters
# origin
# Arizona             1        1          4
# California          2        0         24
# Florida             3        1          2
# Iowa                1        1          4
# Alaska              2        0         24
# ...

# %%
#Select rows where df.deaths is greater than 500 or less than 50 --14
result1 = army[(army['deaths'] > 500) | (army['deaths']<50)]
result1
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona   Nighthawks     1st     523        5  1045         1          1
# Texas     Nighthawks     2nd      25        2  1099        62          3
# Florida   Nighthawks     2nd     616        2  1400        26          3
# Maine       Dragoons     1st      43        4  1592        73          2
# Alaska      Dragoons     2nd     523        8   987       949          2
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#           readiness  armored  deserters
# origin
# Arizona           1        1          4
# Texas             3        1         31
# Florida           3        1          2
# Maine             2        0          3
# Alaska            2        0         24
# Louisana          2        1          2
# Georgia           3        1          3

# %%
#Select all the regiments not named "Dragoons" --15
result2 = army[army['regiment']!='Dragoons']
result2
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             readiness  armored  deserters
# origin
# Arizona             1        1          4
# California          2        0         24
# Texas               3        1         31
# Florida             3        1          2
# Oregon              2        0          2
# ...

# %%
#Select the rows called Texas and Arizona --16
army.loc[['Texas' , 'Arizona']]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas    Nighthawks     2nd      25        2  1099        62          3
# Arizona  Nighthawks     1st     523        5  1045         1          1
#
#          readiness  armored  deserters
# origin
# Texas            3        1         31
# Arizona          1        1          4

# %%
#Select the third cell in the row named Arizona --17
army.loc['Arizona'][2]
# Out:
# 523

# %%
#Select the third cell in the column named deaths --18
army['deaths'][2]
# Out:
# 25
